# %% [markdown]
# <a href="https://colab.research.google.com/github/Berubell9/Bellweb/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Upload

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c683424-ed5d-4158-b3d5-e84ac145749a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c683424-ed5d-4158-b3d5-e84ac145749a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # อ่านไฟล์ CSV
# * Library คือ **pandas**

# %%
import pandas as pd
df = pd.read_csv('Churn_Modelling.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # Satistics
# * `.describe()` = ค่ากลางของสถิติทั้งหมด (ไม่เเสดงค่าที่ Type Object)
# * `.describe(exclude = ['float','int'])` = เอาค่ากลางของสถิติเฉพาะ int float
# * `.describe(include = ['object'])` = เอาค่ากลางของสถิติเฉพาะ object
#
#
# ---
#
#
# * `.mode()` = ค่าฐานนิยม/ค่าที่มีจำนวนมากที่สุด
# * `.mode(numeric_only = True)` = เอาค่าฐานนิยมเฉพาะ int float
#
#
# ---
#
#
#
# * `.คอลัม.value_counts()` = จำนวนเเต่ละประเภทในคอลัม / จำนวนของเเต่ละ attribute ใน Class

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.describe(exclude = ['float','int'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %%
df.describe(include = ['object'])
# Out:
#        Surname Geography Gender
# count    10000     10000  10000
# unique    2932         3      2
# top      Smith    France   Male
# freq        32      5014   5457

# %% [markdown]
# ---

# %%
df.mode()
# Out:
#       RowNumber  CustomerId Surname  CreditScore Geography Gender   Age  \
# 0             1    15565701   Smith        850.0    France   Male  37.0
# 1             2    15565706     NaN          NaN       NaN    NaN   NaN
# 2             3    15565714     NaN          NaN       NaN    NaN   NaN
# 3             4    15565779     NaN          NaN       NaN    NaN   NaN
# 4             5    15565796     NaN          NaN       NaN    NaN   NaN
# ...         ...         ...     ...          ...       ...    ...   ...
# 9995       9996    15815628     NaN          NaN       NaN    NaN   NaN
# 9996       9997    15815645     NaN          NaN       NaN    NaN   NaN
# 9997       9998    15815656     NaN          NaN       NaN    NaN   NaN
# 9998       9999    15815660     NaN          NaN       NaN    NaN   NaN
# 9999      10000    15815690     NaN          NaN       NaN    NaN   NaN
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Age'].mode()
# Out:
# 0    37
# dtype: int64

# %%
df.mode(numeric_only = True)
# Out:
#       RowNumber  CustomerId  CreditScore   Age  Tenure  Balance  \
# 0             1    15565701        850.0  37.0     2.0      0.0
# 1             2    15565706          NaN   NaN     NaN      NaN
# 2             3    15565714          NaN   NaN     NaN      NaN
# 3             4    15565779          NaN   NaN     NaN      NaN
# 4             5    15565796          NaN   NaN     NaN      NaN
# ...         ...         ...          ...   ...     ...      ...
# 9995       9996    15815628          NaN   NaN     NaN      NaN
# 9996       9997    15815645          NaN   NaN     NaN      NaN
# 9997       9998    15815656          NaN   NaN     NaN      NaN
# 9998       9999    15815660          NaN   NaN     NaN      NaN
# 9999      10000    15815690          NaN   NaN     NaN      NaN
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0               1.0        1.0             1.0         24924.92     0.0
# ...

# %% [markdown]
# ---

# %%
df.Geography.value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %% [markdown]
# # Variance | Coefficient of Variation
# Coefficient of Variation (CV) คือ ค่าสัมประสิทธิ์ของการแปรปรวน  = ใช้วัดการกระจายตัวของข้อมูล
# * Library ของ variation คือ scipy `from scipy.stats import variation`
# * `.var()` = คำนวณความแปรปรวนของข้อมูล

# %%
from scipy.stats import variation

# %%
variation(df['Age'])
# Out:
# 0.26944493955242593

# %% [markdown]
# ---

# %%
df.var()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# RowNumber          8.334167e+06
# CustomerId         5.174815e+09
# CreditScore        9.341860e+03
# Age                1.099941e+02
# Tenure             8.364673e+00
# Balance            3.893436e+09
# NumOfProducts      3.383218e-01
# HasCrCard          2.077905e-01
# IsActiveMember     2.497970e-01
# EstimatedSalary    3.307457e+09
# Exited             1.622225e-01
# dtype: float64

# %%
df.var()['Age']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# 109.99408416841683

# %% [markdown]
# # Type ของคอลัมใน DataSet
# * `.dtypes` = เเสดง Type ของเเต่ละคอลัม

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %% [markdown]
# # Covert DataType
# * `คอลัม.astype(' typeที่จะให้เปลี่ยน ')` = เปลี่ยน Type ของข้อมูล

# %%
df.RowNumber      = df.RowNumber.astype('category')
df.CustomerId     = df.CustomerId.astype('category')
df.HasCrCard      = df.HasCrCard.astype('category')
df.IsActiveMember = df.IsActiveMember.astype('category')
df.Exited         = df.Exited.astype('category')
df.NumOfProducts  = df.NumOfProducts.astype('category')
df.Geography      = df.Geography.astype('category')
df.Surname        = df.Surname.astype('category')
df.Gender         = df.Gender.astype('category')

# %%
df.dtypes
# Out:
# RowNumber          category
# CustomerId         category
# Surname            category
# CreditScore           int64
# Geography          category
# Gender             category
# Age                   int64
# Tenure                int64
# Balance             float64
# NumOfProducts      category
# HasCrCard          category
# IsActiveMember     category
# EstimatedSalary     float64
# Exited             category
# dtype: object

# %%
df.describe(include = 'category')
# Out:
#         RowNumber  CustomerId Surname Geography Gender  NumOfProducts  \
# count       10000       10000   10000     10000  10000          10000
# unique      10000       10000    2932         3      2              4
# top             1    15565701   Smith    France   Male              1
# freq            1           1      32      5014   5457           5084
#
#         HasCrCard  IsActiveMember  Exited
# count       10000           10000   10000
# unique          2               2       2
# top             1               1       0
# freq         7055            5151    7963
